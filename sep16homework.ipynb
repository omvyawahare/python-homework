# %% [markdown]
# ### create 5 notebook files
# ### create atleast 3 cells / code block in every file
# ### write print , id, type functions in every file

# %%
print("Hellow python")
# Out:
# Hellow python

# %%
x=100
print (id(x))
# Out:
# 140735241646296

# %%
print(type(x))
# Out:
# <class 'int'>
